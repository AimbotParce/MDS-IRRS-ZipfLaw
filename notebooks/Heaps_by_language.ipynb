# %%
# Load the preprocessed dataset
import os
import pandas as pd

catalog = pd.read_csv("../data/processed/catalog.csv", index_col="id")
print(f"Catalog contains {len(catalog)} books.")

languages = os.listdir("../data/processed/books/")
print(f"Found {len(languages)} languages: {languages}")
# Out:
# Catalog contains 76722 books.
# Found 55 languages: ['af', 'ar', 'arp', 'bg', 'br', 'ca', 'ceb', 'cs', 'cy', 'da', 'de', 'el', 'en', 'enm', 'eo', 'es', 'et', 'fa', 'fi', 'fr', 'fur', 'fy', 'ga', 'gl', 'gla', 'he', 'hu', 'ia', 'ilo', 'is', 'it', 'iu', 'ja', 'la', 'mi', 'myn', 'nah', 'nap', 'nl', 'no', 'oc', 'oji', 'pl', 'pt', 'rmq', 'ro', 'ru', 'sa', 'sco', 'sl', 'sr', 'sv', 'te', 'tl', 'zh']

# %% [markdown]
# For starters, let's check that, for a single language (e.g., English), the Heaps' law holds. We'll first perform single-runs on each book in the language, and then check the distribution of the Heaps' law exponents across books.

# %%
from typing import List, Tuple
import numpy as np


def analyze_vocabulary_growth(words: List[str]):
    vocab = set()
    words_processed = np.arange(1, len(words) + 1, dtype=np.uint32)
    vocab_sizes = np.zeros(len(words), dtype=np.uint32)
    for i, word in enumerate(words):
        vocab.add(word)
        vocab_sizes[i] = len(vocab)

    return words_processed, vocab_sizes, vocab

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")


fig, ax = plt.subplots(1, 2, figsize=(14, 6))

books = os.listdir("../data/processed/books/en/")
for book in books:
    book_id = int(book.removesuffix(".txt"))
    book_info = catalog.loc[book_id]

    print(f"Processing book: {book_id} - {book_info['title']} by {book_info['authors']}")
    with open(os.path.join("../data/processed/books/en/", book), "r", encoding="utf-8") as file:
        words = file.read().split()
    print(f"  Total words in book: {len(words)}")
    words_processed, vocab_sizes, _ = analyze_vocabulary_growth(words)
    ax[0].plot(words_processed, vocab_sizes, label=book_info["title"])
    ax[1].loglog(words_processed, vocab_sizes, label=book_info["title"])


ax[0].set_xlabel("Total Words Processed")
ax[0].set_ylabel("Vocabulary Size (Unique Words)")
ax[0].set_title(f"Heaps' Law: Vocabulary Growth")
ax[0].legend()
ax[1].grid(True, which="both", linestyle="--", linewidth=0.5)  # Add grid for better readability
ax[1].set_xlabel("Total Words Processed (log scale)")
ax[1].set_ylabel("Vocabulary Size (Unique Words) (log scale)")
ax[1].set_title("Heaps' Law: Vocabulary Growth (Log-Log Scale)")
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Processing book: 100 - The Complete Works of William Shakespeare by Shakespeare, William
# Total words in book: 973090
# Processing book: 1342 - Pride and Prejudice by Austen, Jane
# Total words in book: 128093
# Processing book: 145 - Middlemarch by Eliot, George
# Total words in book: 313728
# Processing book: 1513 - Romeo and Juliet by Shakespeare, William
# Total words in book: 29262
# Processing book: 16328 - Beowulf: An Anglo-Saxon Epic Poem by nan
# Total words in book: 37747
# Processing book: 2641 - A Room with a View by Forster, E. M. (Edward Morgan)
# Total words in book: 68141
# Processing book: 2701 - Moby Dick; Or, The Whale by Melville, Herman
# Total words in book: 213169
# Processing book: 37106 - Little Women; Or, Meg, Jo, Beth, and Amy by Alcott, Louisa May
# Total words in book: 192538
# Processing book: 67979 - The Blue Castle: a novel by Montgomery, L. M. (Lucy Maud)
# Total words in book: 70126
# Processing book: 84 - Frankenstein; Or, The Modern Prometheus by Shelley, Mary Wollstonecraft
# Total words in book: 77506

# %%
from scipy.optimize import curve_fit
from sklearn.linear_model import LinearRegression


def func_power_law(x: float, beta: float, K: float) -> float:
    return K * x**beta


fig, ax = plt.subplots(1, 2, figsize=(14, 6))

parameters: List[Tuple[int, int]] = []

books = os.listdir("../data/processed/books/en/")
for col, book in zip(range(len(books)), books):
    book_id = int(book.removesuffix(".txt"))
    book_info = catalog.loc[book_id]

    print(f"Processing book: {book_id} - {book_info['title']} by {book_info['authors']}")
    with open(os.path.join("../data/processed/books/en/", book), "r", encoding="utf-8") as file:
        words = file.read().split()
    print(f"  Total words in book: {len(words)}")
    words_processed, vocab_sizes, _ = analyze_vocabulary_growth(words)
    model = LinearRegression()
    model.fit(np.log(words_processed).reshape(-1, 1), np.log(vocab_sizes).reshape(-1, 1))
    beta_ols = model.coef_[0][0]
    K_ols = np.exp(model.intercept_[0])
    print(f"  Fitted parameters with OLS: K = {K_ols:.4f}, beta = {beta_ols:.4f}")
    (beta_curve_fit, K_curve_fit), pcov = curve_fit(func_power_law, words_processed, vocab_sizes, p0=[beta_ols, K_ols])
    print(f"  Fitted parameters with curve_fit: K = {K_curve_fit:.4f}, beta = {beta_curve_fit:.4f}")

    parameters.append((K_curve_fit, beta_curve_fit))

    ax[0].plot(words_processed, vocab_sizes, label=book_info["title"], color=f"C{col}", alpha=0.5)
    ax[0].plot(words_processed, K_curve_fit * words_processed**beta_curve_fit, linestyle="--", color=f"C{col}")
    ax[1].plot(words_processed, vocab_sizes, label=book_info["title"], color=f"C{col}")


ax[0].set_xlabel("Total Words Processed")
ax[0].set_ylabel("Vocabulary Size (Unique Words)")
ax[0].set_title(f"Heaps' Law: Vocabulary Growth")
ax[0].legend()
ax[1].grid(True, which="both", linestyle="--", linewidth=0.5)  # Add grid for better readability
ax[1].set_xscale("log")
ax[1].set_yscale("log")
ax[1].set_xlabel("Total Words Processed (log scale)")
ax[1].set_ylabel("Vocabulary Size (Unique Words) (log scale)")
ax[1].set_title("Heaps' Law: Vocabulary Growth (Log-Log Scale)")
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Processing book: 100 - The Complete Works of William Shakespeare by Shakespeare, William
#   Total words in book: 973090
#   Fitted parameters with OLS: K = 21.5683, beta = 0.5126
#   Fitted parameters with curve_fit: K = 45.8162, beta = 0.4549
# Processing book: 1342 - Pride and Prejudice by Austen, Jane
#   Total words in book: 128093
#   Fitted parameters with OLS: K = 17.8689, beta = 0.5109
#   Fitted parameters with curve_fit: K = 39.5742, beta = 0.4386
# Processing book: 145 - Middlemarch by Eliot, George
#   Total words in book: 313728
#   Fitted parameters with OLS: K = 15.6303, beta = 0.5486
#   Fitted parameters with curve_fit: K = 38.1192, beta = 0.4739
# Processing book: 1513 - Romeo and Juliet by Shakespeare, William
#   Total words in book: 29262
#   Fitted parameters with OLS: K = 3.1574, beta = 0.6954
#   Fitted parameters with curve_fit: K = 7.3930, beta = 0.6066
# Processing book: 16328 - Beowulf: An Anglo-Saxon Epic Poem by nan
#   Total words in book: 37747
#   Fitted parameters with OLS: K = 4.7121, beta = 0.6730
#   Fitted parameters with curve_fit: K = 12.5401, beta = 0.5735
# Processing book: 2641 - A Room with a View by Forster, E. M. (Edward Morgan)
#   Total words in book: 68141
#   Fitted parameters with OLS: K = 4.5826, beta = 0.6626
#   Fitted parameters with curve_fit: K = 11.0645, beta = 0.5782
# Processing book: 2701 - Moby Dick; Or, The Whale by Melville, Herman
#   Total words in book: 213169
#   Fitted parameters with OLS: K = 7.3116, beta = 0.6360
#   Fitted parameters with curve_fit: K = 16.9214, beta = 0.5634
# Processing book: 37106 - Little Women; Or, Meg, Jo, Beth, and Amy by Alcott, Louisa May
#   Total words in book: 192538
#   Fitted parameters with OLS: K = 11.7223, beta = 0.5612
#   Fitted parameters with curve_fit: K = 16.8688, beta = 0.5293
# Processing book: 67979 - The Blue Castle: a novel by Montgomery, L. M. (Lucy Maud)
#   Total words in book: 70126
#   Fitted parameters with OLS: K = 6.0115, beta = 0.6337
#   Fitted parameters with curve_fit: K = 10.0674, beta = 0.5842
# Processing book: 84 - Frankenstein; Or, The Modern Prometheus by Shelley, Mary Wollstonecraft
#   Total words in book: 77506
#   Fitted parameters with OLS: K = 8.7859, beta = 0.6024
#   Fitted parameters with curve_fit: K = 24.7683, beta = 0.5039

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 6))
ax[0].boxplot(x=[param[1] for param in parameters])
ax[0].set_ylabel("Beta Parameter")
ax[0].set_xticks([1])
ax[0].set_xticklabels(["Books in English"])

ax[1].boxplot(x=[param[0] for param in parameters])
ax[1].set_ylabel("K Parameter")
ax[1].set_xticks([1])
ax[1].set_xticklabels(["Books in English"])
fig.suptitle("Distribution of Fitted Parameters from Heaps' Law")
plt.tight_layout()

# %% [markdown]
# This is curious. We will do the following: We'll perform single-runs through all the books and store their fitted results by language.

# %%
parameters: List[Tuple[str, int, int]] = []
for lang in languages:
    books = os.listdir(f"../data/processed/books/{lang}/")
    for book in books:
        book_id = int(book.removesuffix(".txt"))
        book_info = catalog.loc[book_id]

        print(f"Processing book: {book_id} - {book_info['title']} by {book_info['authors']}")
        with open(os.path.join(f"../data/processed/books", lang, book), "r", encoding="utf-8") as file:
            words = file.read().split()
        print(f"  Total words in book: {len(words)}")
        words_processed, vocab_sizes, _ = analyze_vocabulary_growth(words)
        model = LinearRegression()
        model.fit(np.log(words_processed).reshape(-1, 1), np.log(vocab_sizes).reshape(-1, 1))
        beta_ols = model.coef_[0][0]
        K_ols = np.exp(model.intercept_[0])
        print(f"  Fitted parameters with OLS: K = {K_ols:.4f}, beta = {beta_ols:.4f}")
        (beta_curve_fit, K_curve_fit), pcov = curve_fit(
            func_power_law, words_processed, vocab_sizes, p0=[beta_ols, K_ols]
        )
        print(f"  Fitted parameters with curve_fit: K = {K_curve_fit:.4f}, beta = {beta_curve_fit:.4f}")

        parameters.append((lang, K_curve_fit, beta_curve_fit))
parameters = pd.DataFrame(parameters, columns=["language", "K", "beta"])
# Out:
# Processing book: 16543 - Trekkerswee Met tekeninge van J.H. Pierneef by Totius
#   Total words in book: 11991
#   Fitted parameters with OLS: K = 2.6864, beta = 0.7448
#   Fitted parameters with curve_fit: K = 4.1197, beta = 0.6954
# Processing book: 18203 - Die prosa van die twede Afrikaanse beweging by Schoonees, P. C. (Pieter Cornelis)
#   Total words in book: 102316
#   Fitted parameters with OLS: K = 3.1228, beta = 0.7364
#   Fitted parameters with curve_fit: K = 4.2514, beta = 0.7079
# Processing book: 19729 - Oom Gert Vertel en Ander Gedigte by Leipoldt, C. Louis (Christiaan Louis)
#   Total words in book: 23745
#   Fitted parameters with OLS: K = 4.2458, beta = 0.6779
#   Fitted parameters with curve_fit: K = 8.0594, beta = 0.6093
# Processing book: 42302 - Digters uit Suid-Afrika  Bloemlesing uit die poësie van die Twede Afrikaanse-Taalbeweging by Celliers, Jan F. E. (Jan François Elias);Leipoldt, C. Louis (Christiaan Louis);Malherbe, Daniel François;Totius
#   Total words in book: 24300
#   Fitted parameters with OLS: K = 3.0373, beta = 0.7304
#   Fitted parameters with curve_fit: K = 4.1655, beta = 0.6966
# Processing book: 62330 - Boesman-Stories, Deel 1. Mitologie en legendes by Von Wielligh, G. R. (Gideon Retief)
#   Total words in book: 31941
#   Fitted parameters with OLS: K = 8.5660, beta = 0.5699
#   Fitted parameters with curve_fit: K = 13.4396, beta = 0.5228
# Processing book: 63493 - Boesman-Stories, Deel 2. Dierstories en ander verhale by Von Wielligh, G. R. (Gideon Retief)
#   Total words in book: 33730
#   Fitted parameters with OLS: K = 7.5944, beta = 0.5840
#   Fitted parameters with curve_fit: K = 8.8446, beta = 0.5679
# Processing book: 63998 - Boesman-Stories, Deel 3. Die boesman self, sy sedes, gewoontes en bekwaamhede by Von Wielligh, G. R. (Gideon Retief)
#   Total words in book: 29116
#   Fitted parameters with OLS: K = 4.4763, beta = 0.6650
#   Fitted parameters with curve_fit: K = 7.5563, beta = 0.6100
# Processing book: 64676 - Boesman-Stories, Deel 4. Gemengde Vertellings, mees van 'n Awontuurlike Aard by Von Wielligh, G. R. (Gideon Retief)
#   Total words in book: 31445
#   Fitted parameters with OLS: K = 6.5132, beta = 0.6143
#   Fitted parameters with curve_fit: K = 11.0638, beta = 0.5591
# Processing book: 70421 - Dingaansdag by Leipoldt, C. Louis (Christiaan Louis)
#   Total words in book: 19325
#   Fitted parameters with OLS: K = 3.6634, beta = 0.7003
#   Fitted parameters with curve_fit: K = 5.7591, beta = 0.6506
# Processing book: 72345 - Bang vir die lewe by Bordeaux, Henry
#   Total words in book: 70785
#   Fitted parameters with OLS: K = 6.6533, beta = 0.6146
#   Fitted parameters with curve_fit: K = 8.1456, beta = 0.5950
# Processing book: 43007 - Tribute to Michael Hart by AlHydar, Majid
#   Total words in book: 4745
#   Fitted parameters with OLS: K = 1.9516, beta = 0.8247
#   Fitted parameters with curve_fit: K = 10.5480, beta = 0.6089
# Processing book: 24002 - In Arapahoe: Matthew 9, 1-8. by nan
#   Total words in book: 3296
#   Fitted parameters with OLS: K = 2.5016, beta = 0.7050
#   Fitted parameters with curve_fit: K = 2.9246, beta = 0.6832
# Processing book: 30102 - Hethadenee waunauyaunee vadan Luke vanenana The Gospel According to Saint Luke by nan
#   Total words in book: 17205
#   Fitted parameters with OLS: K = 1.3226, beta = 0.8711
#   Fitted parameters with curve_fit: K = 2.1571, beta = 0.8177
# Processing book: 10752 - Мислите в главите by Stojan, Harry
#   Total words in book: 43339
#   Fitted parameters with OLS: K = 4.1003, beta = 0.6920
#   Fitted parameters with curve_fit: K = 5.2973, beta = 0.6661
# Processing book: 2790 - Христо Ботев, Стихотворения by Botev, Khristo
#   Total words in book: 7775
#   Fitted parameters with OLS: K = 1.7789, beta = 0.8191
#   Fitted parameters with curve_fit: K = 3.9805, beta = 0.7224
# Processing book: 2890 - Епопея на забравените by Vazov, Ivan Minchov
#   Total words in book: 10776
#   Fitted parameters with OLS: K = 1.5203, beta = 0.8581
#   Fitted parameters with curve_fit: K = 4.2577, beta = 0.7391
# Processing book: 2894 - Short Stories by Botev, Khristo
#   Total words in book: 10286
#   Fitted parameters with OLS: K = 1.6017, beta = 0.8421
#   Fitted parameters with curve_fit: K = 3.1476, beta = 0.7637
# Processing book: 3433 - Епически песни by Slaveikov, Pencho P.
#   Total words in book: 13506
#   Fitted parameters with OLS: K = 2.2421, beta = 0.8018
#   Fitted parameters with curve_fit: K = 5.1986, beta = 0.7067
# Processing book: 4909 - Олаф ван Гелдерн by Slaveikov, Pencho P.
#   Total words in book: 5350
#   Fitted parameters with OLS: K = 1.8185, beta = 0.8133
#   Fitted parameters with curve_fit: K = 5.2870, beta = 0.6792
# Processing book: 23685 - Sarmoniou an Aotrou Quere by Quéré, Jean
#   Total words in book: 83532
#   Fitted parameters with OLS: K = 7.3562, beta = 0.6193
#   Fitted parameters with curve_fit: K = 15.2801, beta = 0.5503
# Processing book: 19664 - Els Deu Mil  And Vida D'artaxerxes, Per Plutarc by Xenophon;Plutarch
#   Total words in book: 79847
#   Fitted parameters with OLS: K = 5.1681, beta = 0.6533
#   Fitted parameters with curve_fit: K = 6.0038, beta = 0.6389
# Processing book: 23021 - Sang Nova Novel, la muntanyenca (Volumes 1 and 2) by Vayreda, Marià
#   Total words in book: 91132
#   Fitted parameters with OLS: K = 4.0729, beta = 0.7139
#   Fitted parameters with curve_fit: K = 7.2270, beta = 0.6604
# Processing book: 27142 - Contes D'Andersen by Andersen, H. C. (Hans Christian)
#   Total words in book: 37076
#   Fitted parameters with OLS: K = 4.2721, beta = 0.6949
#   Fitted parameters with curve_fit: K = 11.1978, beta = 0.5967
# Processing book: 29944 - Tres Homes Dins D'una Barca (Sense comptar-hi el gos) by Jerome, Jerome K. (Jerome Klapka)
#   Total words in book: 61916
#   Fitted parameters with OLS: K = 3.7091, beta = 0.7112
#   Fitted parameters with curve_fit: K = 6.7233, beta = 0.6536
# Processing book: 30890 - Les Aventures De Tom Sawyer by Twain, Mark
#   Total words in book: 71106
#   Fitted parameters with OLS: K = 4.0174, beta = 0.6983
#   Fitted parameters with curve_fit: K = 7.2305, beta = 0.6423
# Processing book: 56856 - L'auca del senyor Esteve ab redolins dibuixats per en Ramón Casas; escrits per en Gabriel Alomar by Rusiñol, Santiago
#   Total words in book: 50796
#   Fitted parameters with OLS: K = 4.1680, beta = 0.6819
#   Fitted parameters with curve_fit: K = 6.9061, beta = 0.6320
# Processing book: 72856 - L'escanya-pobres by Oller, Narcís
#   Total words in book: 22274
#   Fitted parameters with OLS: K = 2.6169, beta = 0.7706
#   Fitted parameters with curve_fit: K = 4.6916, beta = 0.7079
# Processing book: 74649 - El meu amic Pellini i altres contes by Bertrana, Prudenci
#   Total words in book: 34316
#   Fitted parameters with OLS: K = 1.9719, beta = 0.8078
#   Fitted parameters with curve_fit: K = 2.3287, beta = 0.7906
# Processing book: 75037 - Escenas de la vida pagesa by Riera i Bertran, Joaquim
#   Total words in book: 34917
#   Fitted parameters with OLS: K = 2.3169, beta = 0.7792
#   Fitted parameters with curve_fit: K = 3.7231, beta = 0.7308
# Processing book: 75136 - La orfaneta de Menargues; o, Catalunya agonisant : $b Novela histórica by Bofarull, Antoni de
#   Total words in book: 203336
#   Fitted parameters with OLS: K = 7.7928, beta = 0.6266
#   Fitted parameters with curve_fit: K = 12.7782, beta = 0.5836
# Processing book: 20820 - Larawan: Mga Sugilanon ug Dinalídalí by Rama, Vincente
#   Total words in book: 18111
#   Fitted parameters with OLS: K = 2.6010, beta = 0.7421
#   Fitted parameters with curve_fit: K = 3.7102, beta = 0.7028
# Processing book: 47869 - Wala'y Igsoon.... (Sugilanon'g Binisaya) by Irles, Juan Villagonzalo
#   Total words in book: 12163
#   Fitted parameters with OLS: K = 2.0761, beta = 0.7629
#   Fitted parameters with curve_fit: K = 2.0402, beta = 0.7646
# Processing book: 13083 - R.U.R. by Čapek, Karel
#   Total words in book: 20982
#   Fitted parameters with OLS: K = 3.4551, beta = 0.7342
#   Fitted parameters with curve_fit: K = 5.3684, beta = 0.6862
# Processing book: 16843 - Cvičení maličkých ve svatém náboženství křesťansko-katolickém by Obdržálek, Peregrin
#   Total words in book: 6995
#   Fitted parameters with OLS: K = 1.7993, beta = 0.8228
#   Fitted parameters with curve_fit: K = 4.2550, beta = 0.7181
# Processing book: 27974 - Vlci proti Mustangům by Omelka, František
#   Total words in book: 40991
#   Fitted parameters with OLS: K = 3.2533, beta = 0.7432
#   Fitted parameters with curve_fit: K = 4.4674, beta = 0.7111
# Processing book: 29592 - Pasáček Ali: Pověst z východu by Omelka, František
#   Total words in book: 9600
#   Fitted parameters with OLS: K = 1.6851, beta = 0.8382
#   Fitted parameters with curve_fit: K = 4.8577, beta = 0.7141
# Processing book: 29648 - Štafeta by Omelka, František
#   Total words in book: 17339
#   Fitted parameters with OLS: K = 2.1712, beta = 0.8098
#   Fitted parameters with curve_fit: K = 3.7790, beta = 0.7486
# Processing book: 34225 - Zápisky z mrtvého domu by Dostoyevsky, Fyodor
#   Total words in book: 111231
#   Fitted parameters with OLS: K = 4.8466, beta = 0.7214
#   Fitted parameters with curve_fit: K = 6.9499, beta = 0.6882
# Processing book: 37525 - Dvojník. Nétička Nezvánova a Malinký Hrdina by Dostoyevsky, Fyodor
#   Total words in book: 122969
#   Fitted parameters with OLS: K = 4.5550, beta = 0.7158
#   Fitted parameters with curve_fit: K = 5.0966, beta = 0.7054
# Processing book: 47754 - Blesky nad Beskydami by Omelka, František
#   Total words in book: 47836
#   Fitted parameters with OLS: K = 3.9005, beta = 0.7472
#   Fitted parameters with curve_fit: K = 7.5381, beta = 0.6816
# Processing book: 59765 - Cítanka pro skoly obecné. Díl I by Stastný, Jan;Lepar, Jan;Sokol, Josef
#   Total words in book: 11370
#   Fitted parameters with OLS: K = 0.4416, beta = 0.9824
#   Fitted parameters with curve_fit: K = 0.8748, beta = 0.9067
# Processing book: 68828 - Sto jisker ethických by Batěk, Alexandr
#   Total words in book: 5927
#   Fitted parameters with OLS: K = 1.7924, beta = 0.8357
#   Fitted parameters with curve_fit: K = 7.0800, beta = 0.6651
# Processing book: 14354 - Gwaith Samuel Roberts by Roberts, Samuel
#   Total words in book: 30825
#   Fitted parameters with OLS: K = 3.9358, beta = 0.7107
#   Fitted parameters with curve_fit: K = 10.3257, beta = 0.6107
# Processing book: 14547 - Gwaith Mynyddog.  Cyfrol II by Mynyddog
#   Total words in book: 20726
#   Fitted parameters with OLS: K = 3.1334, beta = 0.7302
#   Fitted parameters with curve_fit: K = 5.2834, beta = 0.6735
# Processing book: 22528 - Cerddi'r Mynydd Du  Sef Caneuon Hen a Diweddar by nan
#   Total words in book: 12240
#   Fitted parameters with OLS: K = 2.1898, beta = 0.7806
#   Fitted parameters with curve_fit: K = 3.4498, beta = 0.7285
# Processing book: 2734 - Gwaith Twm o'r Nant Cyfrol 2 by Edwards, Thomas
#   Total words in book: 21265
#   Fitted parameters with OLS: K = 2.5427, beta = 0.7729
#   Fitted parameters with curve_fit: K = 5.2139, beta = 0.6953
# Processing book: 3500 - Ceiriog by Hughes, John Ceiriog
#   Total words in book: 21967
#   Fitted parameters with OLS: K = 2.9610, beta = 0.7397
#   Fitted parameters with curve_fit: K = 5.1615, beta = 0.6798
# Processing book: 49685 - Geiriadur Cymraeg a Saesneg Byr by Edwards, Owen Morgan, Sir
#   Total words in book: 47619
#   Fitted parameters with OLS: K = 1.7559, beta = 0.8692
#   Fitted parameters with curve_fit: K = 3.5104, beta = 0.8005
# Processing book: 56275 - I'r Aifft Ac Yn Ol by Jones, D. Rhagfyr
#   Total words in book: 42754
#   Fitted parameters with OLS: K = 4.1252, beta = 0.6952
#   Fitted parameters with curve_fit: K = 6.4684, beta = 0.6499
# Processing book: 67424 - Nedw by Davies, E. Tegla (Edward Tegla)
#   Total words in book: 41939
#   Fitted parameters with OLS: K = 5.6523, beta = 0.6218
#   Fitted parameters with curve_fit: K = 5.8811, beta = 0.6174
# Processing book: 68973 - Y ddwy chwaer: Ffeithiau hanesyddol by Anonymous
#   Total words in book: 13543
#   Fitted parameters with OLS: K = 2.4929, beta = 0.7569
#   Fitted parameters with curve_fit: K = 4.1758, beta = 0.6983
# Processing book: 8194 - Yr Hwiangerddi by Edwards, Owen Morgan, Sir
#   Total words in book: 13088
#   Fitted parameters with OLS: K = 2.1255, beta = 0.7824
#   Fitted parameters with curve_fit: K = 3.3732, beta = 0.7299
# Processing book: 12698 - Stuk by Bang, Herman
#   Total words in book: 76503
#   Fitted parameters with OLS: K = 5.0992, beta = 0.6789
#   Fitted parameters with curve_fit: K = 9.6745, beta = 0.6181
# Processing book: 24486 - Samlede Værker, Første Bind by Aakjær, Jeppe
#   Total words in book: 58894
#   Fitted parameters with OLS: K = 3.4598, beta = 0.7425
#   Fitted parameters with curve_fit: K = 5.4166, beta = 0.6989
# Processing book: 24747 - Samlede Værker, Andet Bind by Aakjær, Jeppe
#   Total words in book: 54031
#   Fitted parameters with OLS: K = 4.5394, beta = 0.7168
#   Fitted parameters with curve_fit: K = 8.7499, beta = 0.6524
# Processing book: 34178 - Græsk Mythologi by Holten-Bechtolsheim, Hans
#   Total words in book: 20439
#   Fitted parameters with OLS: K = 2.6077, beta = 0.7645
#   Fitted parameters with curve_fit: K = 3.4786, beta = 0.7329
# Processing book: 34213 - Kort og sandfærdig Beretning om den vidtudraabte Besættelse udi Thisted by Árni Magnússon
#   Total words in book: 23279
#   Fitted parameters with OLS: K = 4.5675, beta = 0.6702
#   Fitted parameters with curve_fit: K = 6.4553, beta = 0.6328
# Processing book: 36942 - Kongens Fald by Jensen, Johannes V. (Johannes Vilhelm)
#   Total words in book: 72789
#   Fitted parameters with OLS: K = 4.0492, beta = 0.7021
#   Fitted parameters with curve_fit: K = 6.0803, beta = 0.6634
# Processing book: 38515 - Julies Dagbog by Nansen, Peter
#   Total words in book: 49739
#   Fitted parameters with OLS: K = 5.5137, beta = 0.6630
#   Fitted parameters with curve_fit: K = 9.8704, beta = 0.6050
# Processing book: 41277 - Germanernes Lærling by Gjellerup, Karl
#   Total words in book: 100190
#   Fitted parameters with OLS: K = 3.8221, beta = 0.7218
#   Fitted parameters with curve_fit: K = 7.6372, beta = 0.6580
# Processing book: 76563 - Pelle Erobreren 1: Barndom by Andersen Nexø, Martin
#   Total words in book: 102643
#   Fitted parameters with OLS: K = 7.5481, beta = 0.6314
#   Fitted parameters with curve_fit: K = 12.8228, beta = 0.5823
# Processing book: 76723 - Pelle Erobreren 2: Læreaar by Andersen Nexø, Martin
#   Total words in book: 91507
#   Fitted parameters with OLS: K = 5.3274, beta = 0.6662
#   Fitted parameters with curve_fit: K = 8.9469, beta = 0.6178
# Processing book: 22367 - Die Verwandlung by Kafka, Franz
#   Total words in book: 22081
#   Fitted parameters with OLS: K = 3.7731, beta = 0.7050
#   Fitted parameters with curve_fit: K = 4.8992, beta = 0.6765
# Processing book: 24571 - Der Struwwelpeter oder lustige Geschichten und drollige Bilder by Hoffmann, Heinrich
#   Total words in book: 5901
#   Fitted parameters with OLS: K = 2.4957, beta = 0.7629
#   Fitted parameters with curve_fit: K = 6.1772, beta = 0.6496
# Processing book: 31284 - Josefine Mutzenbacher oder Die Geschichte einer Wienerischen Dirne von ihr selbst erzählt by Salten, Felix
#   Total words in book: 70079
#   Fitted parameters with OLS: K = 8.4226, beta = 0.5966
#   Fitted parameters with curve_fit: K = 8.0893, beta = 0.6000
# Processing book: 39762 - Etymologisches Wörterbuch der deutschen Seemannssprache by Goedel, Gustav
#   Total words in book: 176863
#   Fitted parameters with OLS: K = 3.0712, beta = 0.7604
#   Fitted parameters with curve_fit: K = 5.6057, beta = 0.7077
# Processing book: 43759 - Geflügelte Worte: Der Citatenschatz des deutschen Volkes by Büchmann, Georg;Robert-tornow, Walter
#   Total words in book: 161400
#   Fitted parameters with OLS: K = 2.8787, beta = 0.7662
#   Fitted parameters with curve_fit: K = 8.8097, beta = 0.6683
# Processing book: 47406 - Aphorismen zur Lebensweisheit by Schopenhauer, Arthur
#   Total words in book: 68413
#   Fitted parameters with OLS: K = 4.0140, beta = 0.7149
#   Fitted parameters with curve_fit: K = 6.0120, beta = 0.6762
# Processing book: 51221 - Geschlecht und Charakter: Eine prinzipielle Untersuchung by Weininger, Otto
#   Total words in book: 184975
#   Fitted parameters with OLS: K = 6.1085, beta = 0.6693
#   Fitted parameters with curve_fit: K = 4.7629, beta = 0.6904
# Processing book: 58804 - Die Deutschen Familiennamen, geschichtlich, geographisch, sprachlich by Heintze, Albert
#   Total words in book: 75553
#   Fitted parameters with OLS: K = 1.7555, beta = 0.8136
#   Fitted parameters with curve_fit: K = 0.7101, beta = 0.8986
# Processing book: 68400 - Der Marquis de Sade und seine Zeit. by Bloch, Iwan
#   Total words in book: 122014
#   Fitted parameters with OLS: K = 3.3792, beta = 0.7452
#   Fitted parameters with curve_fit: K = 7.2864, beta = 0.6757
# Processing book: 7205 - Also sprach Zarathustra: Ein Buch für Alle und Keinen by Nietzsche, Friedrich Wilhelm
#   Total words in book: 83633
#   Fitted parameters with OLS: K = 3.6603, beta = 0.6939
#   Fitted parameters with curve_fit: K = 3.8456, beta = 0.6892
# Processing book: 27816 - Περί Ψυχής by Aristotle
#   Total words in book: 50681
#   Fitted parameters with OLS: K = 6.4130, beta = 0.6351
#   Fitted parameters with curve_fit: K = 9.3678, beta = 0.5972
# Processing book: 28658 - Καλαμιές στον άνεμο by Deledda, Grazia
#   Total words in book: 67571
#   Fitted parameters with OLS: K = 5.7607, beta = 0.6721
#   Fitted parameters with curve_fit: K = 11.1875, beta = 0.6082
# Processing book: 34767 - Στοχασμοί by Wilde, Oscar
#   Total words in book: 64394
#   Fitted parameters with OLS: K = 3.3060, beta = 0.7536
#   Fitted parameters with curve_fit: K = 6.3629, beta = 0.6905
# Processing book: 35453 - Τίμαιος, Τόμος Α by Plato
#   Total words in book: 34655
#   Fitted parameters with OLS: K = 3.4516, beta = 0.7335
#   Fitted parameters with curve_fit: K = 6.4182, beta = 0.6698
# Processing book: 36248 - Ιλιάδα by Homer
#   Total words in book: 112951
#   Fitted parameters with OLS: K = 5.0702, beta = 0.6850
#   Fitted parameters with curve_fit: K = 8.3857, beta = 0.6389
# Processing book: 38055 - Ιστορίαι Ηροδότου, Τόμος 1 by Herodotus
#   Total words in book: 113751
#   Fitted parameters with OLS: K = 3.8661, beta = 0.7262
#   Fitted parameters with curve_fit: K = 5.9897, beta = 0.6862
# Processing book: 41684 - Εγχειρίδιον Βυζαντινής Ιστορίας by Karolides, Paulos
#   Total words in book: 112612
#   Fitted parameters with OLS: K = 3.2501, beta = 0.7370
#   Fitted parameters with curve_fit: K = 5.0550, beta = 0.6966
# Processing book: 42031 - Διονυσίου Σολωμού - Άπαντα τα Ευρισκόμενα by Solomos, Dionysios
#   Total words in book: 80394
#   Fitted parameters with OLS: K = 1.7966, beta = 0.8158
#   Fitted parameters with curve_fit: K = 1.0253, beta = 0.8681
# Processing book: 42700 - Πλουτάρχου Βίοι Παράλληλοι - Τόμος 3  Αλκιβιάδης - Κοριολάνος - Τιμολέων - Αιμίλιος Παύλος - Πελοπίδας - Μάρκελλος by Plutarch
#   Total words in book: 79043
#   Fitted parameters with OLS: K = 2.7792, beta = 0.7664
#   Fitted parameters with curve_fit: K = 3.3558, beta = 0.7484
# Processing book: 57629 - Lucian's Dialogues prepared for schools by Lucian, of Samosata
#   Total words in book: 36291
#   Fitted parameters with OLS: K = 0.8717, beta = 0.9001
#   Fitted parameters with curve_fit: K = 1.3309, beta = 0.8574
# Processing book: 100 - The Complete Works of William Shakespeare by Shakespeare, William
#   Total words in book: 973090
#   Fitted parameters with OLS: K = 21.5683, beta = 0.5126
#   Fitted parameters with curve_fit: K = 45.8162, beta = 0.4549
# Processing book: 1342 - Pride and Prejudice by Austen, Jane
#   Total words in book: 128093
#   Fitted parameters with OLS: K = 17.8689, beta = 0.5109
#   Fitted parameters with curve_fit: K = 39.5742, beta = 0.4386
# Processing book: 145 - Middlemarch by Eliot, George
#   Total words in book: 313728
#   Fitted parameters with OLS: K = 15.6303, beta = 0.5486
#   Fitted parameters with curve_fit: K = 38.1192, beta = 0.4739
# Processing book: 1513 - Romeo and Juliet by Shakespeare, William
#   Total words in book: 29262
#   Fitted parameters with OLS: K = 3.1574, beta = 0.6954
#   Fitted parameters with curve_fit: K = 7.3930, beta = 0.6066
# Processing book: 16328 - Beowulf: An Anglo-Saxon Epic Poem by nan
#   Total words in book: 37747
#   Fitted parameters with OLS: K = 4.7121, beta = 0.6730
#   Fitted parameters with curve_fit: K = 12.5401, beta = 0.5735
# Processing book: 2641 - A Room with a View by Forster, E. M. (Edward Morgan)
#   Total words in book: 68141
#   Fitted parameters with OLS: K = 4.5826, beta = 0.6626
#   Fitted parameters with curve_fit: K = 11.0645, beta = 0.5782
# Processing book: 2701 - Moby Dick; Or, The Whale by Melville, Herman
#   Total words in book: 213169
#   Fitted parameters with OLS: K = 7.3116, beta = 0.6360
#   Fitted parameters with curve_fit: K = 16.9214, beta = 0.5634
# Processing book: 37106 - Little Women; Or, Meg, Jo, Beth, and Amy by Alcott, Louisa May
#   Total words in book: 192538
#   Fitted parameters with OLS: K = 11.7223, beta = 0.5612
#   Fitted parameters with curve_fit: K = 16.8688, beta = 0.5293
# Processing book: 67979 - The Blue Castle: a novel by Montgomery, L. M. (Lucy Maud)
#   Total words in book: 70126
#   Fitted parameters with OLS: K = 6.0115, beta = 0.6337
#   Fitted parameters with curve_fit: K = 10.0674, beta = 0.5842
# Processing book: 84 - Frankenstein; Or, The Modern Prometheus by Shelley, Mary Wollstonecraft
#   Total words in book: 77506
#   Fitted parameters with OLS: K = 8.7859, beta = 0.6024
#   Fitted parameters with curve_fit: K = 24.7683, beta = 0.5039
# Processing book: 17179 - The Book of Quinte Essence or the Fifth Being (1889)  Edited from British Museum MS. Sloane 73 about 1460-70 A.D. by nan
#   Total words in book: 21804
#   Fitted parameters with OLS: K = 4.0405, beta = 0.6662
#   Fitted parameters with curve_fit: K = 2.5347, beta = 0.7151
# Processing book: 17400 - The Wright's Chaste Wife A Merry Tale (about 1462) by Adam, of Cobsam, active approximately 1462
#   Total words in book: 11380
#   Fitted parameters with OLS: K = 3.0889, beta = 0.7140
#   Fitted parameters with curve_fit: K = 4.5635, beta = 0.6683
# Processing book: 22120 - Chaucer's Works, Volume 4 — The Canterbury Tales by Chaucer, Geoffrey
#   Total words in book: 216197
#   Fitted parameters with OLS: K = 7.3018, beta = 0.6252
#   Fitted parameters with curve_fit: K = 23.4908, beta = 0.5241
# Processing book: 17482 - La Aventuroj de Alicio en Mirlando by Carroll, Lewis
#   Total words in book: 27968
#   Fitted parameters with OLS: K = 4.3834, beta = 0.6937
#   Fitted parameters with curve_fit: K = 7.2802, beta = 0.6401
# Processing book: 20006 - Dua Libro de l' Lingvo Internacia by Zamenhof, L. L. (Ludwik Lejzer)
#   Total words in book: 19238
#   Fitted parameters with OLS: K = 2.6632, beta = 0.7316
#   Fitted parameters with curve_fit: K = 4.5619, beta = 0.6732
# Processing book: 22592 - Ifigenio en Taŭrido by Goethe, Johann Wolfgang von
#   Total words in book: 19307
#   Fitted parameters with OLS: K = 2.7738, beta = 0.7453
#   Fitted parameters with curve_fit: K = 3.8486, beta = 0.7092
# Processing book: 24145 - Doktoro Jekyll kaj Sinjoro Hyde by Stevenson, Robert Louis
#   Total words in book: 26305
#   Fitted parameters with OLS: K = 2.9538, beta = 0.7418
#   Fitted parameters with curve_fit: K = 3.1178, beta = 0.7355
# Processing book: 24292 - La Montarino: la poemaro pri Veslemey by Garborg, Arne
#   Total words in book: 23532
#   Fitted parameters with OLS: K = 2.0738, beta = 0.8053
#   Fitted parameters with curve_fit: K = 3.7933, beta = 0.7410
# Processing book: 26359 - Vivo de Zamenhof by Privat, Edmond
#   Total words in book: 27491
#   Fitted parameters with OLS: K = 3.4448, beta = 0.7450
#   Fitted parameters with curve_fit: K = 7.2414, beta = 0.6668
# Processing book: 44130 - The Esperantist, Vol. 2, No. 4 by nan
#   Total words in book: 14844
#   Fitted parameters with OLS: K = 2.2802, beta = 0.7984
#   Fitted parameters with curve_fit: K = 4.0397, beta = 0.7341
# Processing book: 47913 - Makbeto by Shakespeare, William
#   Total words in book: 19639
#   Fitted parameters with OLS: K = 2.5454, beta = 0.7706
#   Fitted parameters with curve_fit: K = 3.3260, beta = 0.7413
# Processing book: 55302 - Princo Serebrjanij by Tolstoy, Aleksey Konstantinovich, graf
#   Total words in book: 104957
#   Fitted parameters with OLS: K = 7.8458, beta = 0.6394
#   Fitted parameters with curve_fit: K = 16.1117, beta = 0.5729
# Processing book: 8224 - Fundamenta Krestomatio by Zamenhof, L. L. (Ludwik Lejzer)
#   Total words in book: 123851
#   Fitted parameters with OLS: K = 2.8852, beta = 0.7334
#   Fitted parameters with curve_fit: K = 2.5478, beta = 0.7445
# Processing book: 18600 - Mi Ultimo Adiós by Rizal, José
#   Total words in book: 3616
#   Fitted parameters with OLS: K = 2.4101, beta = 0.7463
#   Fitted parameters with curve_fit: K = 7.0678, beta = 0.6032
# Processing book: 2000 - Don Quijote by Cervantes Saavedra, Miguel de
#   Total words in book: 380800
#   Fitted parameters with OLS: K = 7.3356, beta = 0.6293
#   Fitted parameters with curve_fit: K = 12.0758, beta = 0.5879
# Processing book: 33267 - Facundo by Sarmiento, Domingo Faustino
#   Total words in book: 102322
#   Fitted parameters with OLS: K = 4.3373, beta = 0.7045
#   Fitted parameters with curve_fit: K = 9.6792, beta = 0.6304
# Processing book: 36805 - Spanish Tales for Beginners by nan
#   Total words in book: 64778
#   Fitted parameters with OLS: K = 1.9108, beta = 0.7901
#   Fitted parameters with curve_fit: K = 1.4188, beta = 0.8181
# Processing book: 47584 - Noli me tángere Novela Tagala, Edición completa con notas de R. Sempau by Rizal, José
#   Total words in book: 139574
#   Fitted parameters with OLS: K = 6.5066, beta = 0.6673
#   Fitted parameters with curve_fit: K = 12.4273, beta = 0.6092
# Processing book: 57303 - La Divina Comedia by Dante Alighieri
#   Total words in book: 122962
#   Fitted parameters with OLS: K = 4.4707, beta = 0.6951
#   Fitted parameters with curve_fit: K = 10.6345, beta = 0.6165
# Processing book: 58221 - La Odisea by Homer
#   Total words in book: 168792
#   Fitted parameters with OLS: K = 10.7576, beta = 0.6085
#   Fitted parameters with curve_fit: K = 26.1970, beta = 0.5298
# Processing book: 67092 - El paraíso perdido by Milton, John
#   Total words in book: 159882
#   Fitted parameters with OLS: K = 3.9202, beta = 0.7141
#   Fitted parameters with curve_fit: K = 8.9027, beta = 0.6417
# Processing book: 67961 - El arte de amar by Ovid
#   Total words in book: 26576
#   Fitted parameters with OLS: K = 1.9529, beta = 0.8106
#   Fitted parameters with curve_fit: K = 3.2359, beta = 0.7576
# Processing book: 73257 - Historia de la lengua y literatura castellana, Tomo 2 : $b Época de Carlos V by Cejador y Frauca, Julio
#   Total words in book: 116877
#   Fitted parameters with OLS: K = 4.4372, beta = 0.7084
#   Fitted parameters with curve_fit: K = 8.8241, beta = 0.6456
# Processing book: 44217 - Libahunt: Draama wiies vaatuses by Kitzberg, August
#   Total words in book: 14845
#   Fitted parameters with OLS: K = 3.5164, beta = 0.7322
#   Fitted parameters with curve_fit: K = 7.3631, beta = 0.6490
# Processing book: 46740 - Five Selected Short Stories by Lawrence, D. H. (David Herbert)
#   Total words in book: 24067
#   Fitted parameters with OLS: K = 2.8592, beta = 0.7561
#   Fitted parameters with curve_fit: K = 4.7437, beta = 0.7021
# Processing book: 11940 - Seitsemän veljestä Kertomus by Kivi, Aleksis
#   Total words in book: 83211
#   Fitted parameters with OLS: K = 3.2476, beta = 0.7813
#   Fitted parameters with curve_fit: K = 5.1754, beta = 0.7375
# Processing book: 48595 - Ihmisruumiin substanssi suomalais-ugrilaisten kansojen taikuudessa Taikapsykologinen tutkimus by Hämäläinen, Albert
#   Total words in book: 46681
#   Fitted parameters with OLS: K = 2.3969, beta = 0.8078
#   Fitted parameters with curve_fit: K = 3.9546, beta = 0.7582
# Processing book: 66994 - Saul: Murhenäytelmän mukainen runoelma viidessä näytöksessä by Törneroos, Antti
#   Total words in book: 26164
#   Fitted parameters with OLS: K = 2.4347, beta = 0.8090
#   Fitted parameters with curve_fit: K = 4.8014, beta = 0.7374
# Processing book: 7000 - Kalevala by nan
#   Total words in book: 69592
#   Fitted parameters with OLS: K = 3.2638, beta = 0.7884
#   Fitted parameters with curve_fit: K = 5.6650, beta = 0.7356
# Processing book: 70303 - Valkoisella kivellä by France, Anatole
#   Total words in book: 16982
#   Fitted parameters with OLS: K = 1.8266, beta = 0.8565
#   Fitted parameters with curve_fit: K = 3.8275, beta = 0.7750
# Processing book: 7078 - Kanteletar: Suomen kansan wanhoja lauluja ja wirsiä by nan
#   Total words in book: 89616
#   Fitted parameters with OLS: K = 2.9959, beta = 0.8014
#   Fitted parameters with curve_fit: K = 5.7439, beta = 0.7408
# Processing book: 72097 - Voittojen päiviltä by Heidenstam, Verner von
#   Total words in book: 17470
#   Fitted parameters with OLS: K = 1.9577, beta = 0.8479
#   Fitted parameters with curve_fit: K = 3.8402, beta = 0.7737
# Processing book: 73437 - Matkakuvaelmia ja muistoja Lapin rajoilta by Nervander, Emil Fredrik
#   Total words in book: 19349
#   Fitted parameters with OLS: K = 1.6368, beta = 0.8784
#   Fitted parameters with curve_fit: K = 3.7038, beta = 0.7898
# Processing book: 76680 - Kertomuksia Etelä-Pohjanmaalta by Rinta, Matti
#   Total words in book: 23960
#   Fitted parameters with OLS: K = 2.4519, beta = 0.8005
#   Fitted parameters with curve_fit: K = 4.2446, beta = 0.7421
# Processing book: 76687 - Surutar : $b Romaani by Sudermann, Hermann
#   Total words in book: 50719
#   Fitted parameters with OLS: K = 3.2662, beta = 0.7735
#   Fitted parameters with curve_fit: K = 5.0489, beta = 0.7304
# Processing book: 13951 - Les trois mousquetaires by Dumas, Alexandre;Maquet, Auguste
#   Total words in book: 234427
#   Fitted parameters with OLS: K = 12.1399, beta = 0.5715
#   Fitted parameters with curve_fit: K = 17.0600, beta = 0.5421
# Processing book: 17489 - Les misérables Tome I: Fantine by Hugo, Victor
#   Total words in book: 104054
#   Fitted parameters with OLS: K = 4.6479, beta = 0.6831
#   Fitted parameters with curve_fit: K = 9.8327, beta = 0.6142
# Processing book: 17989 - Le comte de Monte-Cristo, Tome I by Dumas, Alexandre;Maquet, Auguste
#   Total words in book: 114655
#   Fitted parameters with OLS: K = 4.4704, beta = 0.6691
#   Fitted parameters with curve_fit: K = 5.9082, beta = 0.6437
# Processing book: 2650 - Du côté de chez Swann by Proust, Marcel
#   Total words in book: 180114
#   Fitted parameters with OLS: K = 6.5178, beta = 0.6467
#   Fitted parameters with curve_fit: K = 15.5312, beta = 0.5706
# Processing book: 34445 - Œuvres de P. Corneille, Tome 02 by Corneille, Pierre
#   Total words in book: 109263
#   Fitted parameters with OLS: K = 8.4829, beta = 0.5974
#   Fitted parameters with curve_fit: K = 6.1549, beta = 0.6262
# Processing book: 44958 - Les quatre livres de philosophie morale et politique de la Chine by Confucius;Mencius
#   Total words in book: 123870
#   Fitted parameters with OLS: K = 8.0475, beta = 0.5991
#   Fitted parameters with curve_fit: K = 12.8256, beta = 0.5567
# Processing book: 60882 - De l'Amour  Édition revue et corrigée et précédée d'une étude sur les oeuvres de Stendhal par Sainte-Beuve by Stendhal
#   Total words in book: 117651
#   Fitted parameters with OLS: K = 6.1507, beta = 0.6515
#   Fitted parameters with curve_fit: K = 7.8682, beta = 0.6288
# Processing book: 6099 - Les Fleurs du Mal by Baudelaire, Charles
#   Total words in book: 25951
#   Fitted parameters with OLS: K = 2.7669, beta = 0.7624
#   Fitted parameters with curve_fit: K = 6.0422, beta = 0.6799
# Processing book: 64830 - Mémoires de Miss Coote: Exploits d'une fouetteuse britannique racontés par elle-même by Coote, Rosa Belinda
#   Total words in book: 36372
#   Fitted parameters with OLS: K = 3.7708, beta = 0.6999
#   Fitted parameters with curve_fit: K = 4.8747, beta = 0.6736
# Processing book: 70891 - Notre-Dame de Paris - Tome 1 by Hugo, Victor
#   Total words in book: 75752
#   Fitted parameters with OLS: K = 3.5885, beta = 0.7173
#   Fitted parameters with curve_fit: K = 5.1913, beta = 0.6823
# Processing book: 16187 - La Divina Comèdia: Infièr (Dante's Inferno) by Dante Alighieri
#   Total words in book: 42739
#   Fitted parameters with OLS: K = 3.9931, beta = 0.6874
#   Fitted parameters with curve_fit: K = 5.3944, beta = 0.6569
# Processing book: 16188 - La Divina Comèdia: Purgatòri English title is Dante's Purgatorio by Dante Alighieri
#   Total words in book: 50264
#   Fitted parameters with OLS: K = 4.9412, beta = 0.6612
#   Fitted parameters with curve_fit: K = 6.1197, beta = 0.6396
# Processing book: 16189 - La Divina Comèdia: Paradìs English title is Dante's Paradise by Dante Alighieri
#   Total words in book: 57178
#   Fitted parameters with OLS: K = 4.8840, beta = 0.6607
#   Fitted parameters with curve_fit: K = 5.9676, beta = 0.6407
# Processing book: 16190 - La Divina Comèdia: Complete English title is Dante's Divine Comedy, Complete by Dante Alighieri
#   Total words in book: 141757
#   Fitted parameters with OLS: K = 6.0388, beta = 0.6402
#   Fitted parameters with curve_fit: K = 7.8244, beta = 0.6166
# Processing book: 27460 - Il Vanzeli di Mateo by nan
#   Total words in book: 28647
#   Fitted parameters with OLS: K = 5.0992, beta = 0.6362
#   Fitted parameters with curve_fit: K = 8.0701, beta = 0.5878
# Processing book: 28487 - Cjantaclàr e Partelote by Chaucer, Geoffrey
#   Total words in book: 8761
#   Fitted parameters with OLS: K = 2.8183, beta = 0.7211
#   Fitted parameters with curve_fit: K = 2.8047, beta = 0.7208
# Processing book: 46459 - Ljocht en Skaed: In mennich biskôgings by Kalma, Douwe
#   Total words in book: 20886
#   Fitted parameters with OLS: K = 2.8668, beta = 0.7329
#   Fitted parameters with curve_fit: K = 3.0784, beta = 0.7246
# Processing book: 60480 - Rimen en Teltsjes by Halbertsma, Justus Hiddes;Halbertsma, Eeltsje;Halbertsma, Tjalling
#   Total words in book: 334393
#   Fitted parameters with OLS: K = 8.0154, beta = 0.6374
#   Fitted parameters with curve_fit: K = 12.7445, beta = 0.5987
# Processing book: 63023 - De Hoara's fen Hastings by Kloosterman, Simke
#   Total words in book: 72349
#   Fitted parameters with OLS: K = 4.7290, beta = 0.6651
#   Fitted parameters with curve_fit: K = 5.0845, beta = 0.6580
# Processing book: 73762 - It Jubeljier : $b (1793-1813) by Kloosterman, Simke
#   Total words in book: 168188
#   Fitted parameters with OLS: K = 5.0430, beta = 0.6780
#   Fitted parameters with curve_fit: K = 9.2294, beta = 0.6246
# Processing book: 73898 - Ruth : $b In hânfol ieren by Kloosterman, Simke
#   Total words in book: 78758
#   Fitted parameters with OLS: K = 4.3535, beta = 0.6864
#   Fitted parameters with curve_fit: K = 8.9684, beta = 0.6182
# Processing book: 73915 - Twiljocht-teltsjes : $b Maerkes by Kloosterman, Simke
#   Total words in book: 33585
#   Fitted parameters with OLS: K = 3.2986, beta = 0.7026
#   Fitted parameters with curve_fit: K = 4.3350, beta = 0.6745
# Processing book: 73982 - Frysce wâldblomkes by Kloosterman, J. R. (Jan Ritskes)
#   Total words in book: 18160
#   Fitted parameters with OLS: K = 2.5151, beta = 0.7646
#   Fitted parameters with curve_fit: K = 3.0426, beta = 0.7434
# Processing book: 74430 - Kening Aldgillis : $b epyske forbylding for great toaniel yn fiif útkomsten by Kalma, Douwe
#   Total words in book: 51969
#   Fitted parameters with OLS: K = 5.9281, beta = 0.6303
#   Fitted parameters with curve_fit: K = 9.2409, beta = 0.5865
# Processing book: 74907 - Fryslân : $b in stik yn njuggen tafrielen yn proaze by Kalma, Douwe
#   Total words in book: 23336
#   Fitted parameters with OLS: K = 2.6080, beta = 0.7265
#   Fitted parameters with curve_fit: K = 3.8636, beta = 0.6845
# Processing book: 75842 - De jongfryske biweging by Kalma, Douwe
#   Total words in book: 39905
#   Fitted parameters with OLS: K = 5.9167, beta = 0.6373
#   Fitted parameters with curve_fit: K = 9.7404, beta = 0.5865
# Processing book: 16122 - Leabhráin an Irisleabhair—III Seanaid na nGaedheal by Chonán Maol;Beirt Fhear;Dinneen, Patrick S. (Patrick Stephen);Gruagach an Tobair
#   Total words in book: 7202
#   Fitted parameters with OLS: K = 2.2776, beta = 0.7662
#   Fitted parameters with curve_fit: K = 3.9828, beta = 0.6979
# Processing book: 50913 - Niamh by O'Leary, Peter
#   Total words in book: 111317
#   Fitted parameters with OLS: K = 13.1004, beta = 0.5327
#   Fitted parameters with curve_fit: K = 19.2030, beta = 0.4975
# Processing book: 21564 - Catecismo d'a Doutrina Labrega by Lamas Carvajal, Valentín
#   Total words in book: 8067
#   Fitted parameters with OLS: K = 2.0598, beta = 0.7821
#   Fitted parameters with curve_fit: K = 3.7243, beta = 0.7109
# Processing book: 59037 - Cantares gallegos by Castro, Rosalía de
#   Total words in book: 23726
#   Fitted parameters with OLS: K = 2.2353, beta = 0.7879
#   Fitted parameters with curve_fit: K = 2.7558, beta = 0.7651
# Processing book: 65703 - Follas Novas: Versos en Gallego by Castro, Rosalía de
#   Total words in book: 35293
#   Fitted parameters with OLS: K = 2.6136, beta = 0.7700
#   Fitted parameters with curve_fit: K = 5.0414, beta = 0.7030
# Processing book: 28995 - Coinneach Odhar, Am Fiosaiche by Blair, D. B.
#   Total words in book: 7994
#   Fitted parameters with OLS: K = 2.2520, beta = 0.7543
#   Fitted parameters with curve_fit: K = 2.9897, beta = 0.7200
# Processing book: 39849 - Gearr-sgeoil air Sir Seoras Uilleam Ros by Fraser, Alexander
#   Total words in book: 13262
#   Fitted parameters with OLS: K = 3.0751, beta = 0.7270
#   Fitted parameters with curve_fit: K = 5.9599, beta = 0.6515
# Processing book: 18291 - Hunger: Book One by Hamsun, Knut
#   Total words in book: 20768
#   Fitted parameters with OLS: K = 3.0296, beta = 0.7761
#   Fitted parameters with curve_fit: K = 7.3138, beta = 0.6808
# Processing book: 43740 - בית נכות ההלכות  או תורתן של ראשונים, חלק ראשון by nan
#   Total words in book: 25190
#   Fitted parameters with OLS: K = 2.1951, beta = 0.8131
#   Fitted parameters with curve_fit: K = 3.0545, beta = 0.7777
# Processing book: 45252 - הצופה לבית ישראל  תשליך by Erter, Isaac
#   Total words in book: 9747
#   Fitted parameters with OLS: K = 1.5796, beta = 0.8627
#   Fitted parameters with curve_fit: K = 3.7115, beta = 0.7628
# Processing book: 4778 - Sipurim (Stories) by Vaknin, Samuel
#   Total words in book: 59578
#   Fitted parameters with OLS: K = 2.8290, beta = 0.8035
#   Fitted parameters with curve_fit: K = 4.6703, beta = 0.7548
# Processing book: 5139 - Tales by Ewald, Carl
#   Total words in book: 70373
#   Fitted parameters with OLS: K = 3.3866, beta = 0.7594
#   Fitted parameters with curve_fit: K = 6.7448, beta = 0.6937
# Processing book: 61024 - צל העולם by Gautier, of Metz, active 1245
#   Total words in book: 16282
#   Fitted parameters with OLS: K = 2.3277, beta = 0.8122
#   Fitted parameters with curve_fit: K = 5.3178, beta = 0.7207
# Processing book: 39649 - Népdalok és mondák (3. kötet); Magyar népköltési gyüjtemény by Erdélyi, János
#   Total words in book: 61938
#   Fitted parameters with OLS: K = 2.4219, beta = 0.7958
#   Fitted parameters with curve_fit: K = 4.7627, beta = 0.7308
# Processing book: 39737 - Magyar népdalok (Magyar remekirók 54. kötet) by Endrődi, Sándor
#   Total words in book: 48981
#   Fitted parameters with OLS: K = 3.6105, beta = 0.7504
#   Fitted parameters with curve_fit: K = 7.2065, beta = 0.6819
# Processing book: 40039 - A magyar nép művészete (1. kötet)  A kalotaszegi magyar nép művészete by Malonyay, Dezső
#   Total words in book: 58167
#   Fitted parameters with OLS: K = 2.4167, beta = 0.8090
#   Fitted parameters with curve_fit: K = 6.0330, beta = 0.7202
# Processing book: 40392 - A magyar népköltés gyöngyei: A legszebb népdalok gyüjteménye by Benedek, Elek
#   Total words in book: 33477
#   Fitted parameters with OLS: K = 3.0885, beta = 0.7532
#   Fitted parameters with curve_fit: K = 3.6975, beta = 0.7342
# Processing book: 41504 - Petőfi Sándor összes költeményei Hazai művészek rajzaival díszített negyedik népies kiadás by Petőfi, Sándor
#   Total words in book: 156898
#   Fitted parameters with OLS: K = 3.7055, beta = 0.7599
#   Fitted parameters with curve_fit: K = 6.7306, beta = 0.7069
# Processing book: 42094 - Székelyföldi gyüjtés; Magyar népköltési gyüjtemény 7. kötet by Mailand, Oszkár
#   Total words in book: 73574
#   Fitted parameters with OLS: K = 4.0846, beta = 0.7412
#   Fitted parameters with curve_fit: K = 10.2944, beta = 0.6533
# Processing book: 42325 - Régi magyar vitézi énekek és elegyes dalok (1. kötet) by Thaly, Kálmán
#   Total words in book: 38516
#   Fitted parameters with OLS: K = 1.6912, beta = 0.8562
#   Fitted parameters with curve_fit: K = 2.5964, beta = 0.8130
# Processing book: 43324 - Csongrádmegyei gyüjtés; Magyar népköltési gyüjtemény 2. kötet by Török, Károly
#   Total words in book: 64039
#   Fitted parameters with OLS: K = 2.5474, beta = 0.7802
#   Fitted parameters with curve_fit: K = 2.0852, beta = 0.7993
# Processing book: 43603 - Népmesék Heves- és Jász-Nagykun-Szolnok-megyéből; Magyar népköltési gyüjtemény 9. kötet by Berze Nagy, János
#   Total words in book: 120552
#   Fitted parameters with OLS: K = 5.8220, beta = 0.6921
#   Fitted parameters with curve_fit: K = 7.0386, beta = 0.6746
# Processing book: 66903 - Emil, vagy a nevelésről by Rousseau, Jean-Jacques
#   Total words in book: 217943
#   Fitted parameters with OLS: K = 3.6604, beta = 0.7543
#   Fitted parameters with curve_fit: K = 5.7009, beta = 0.7162
# Processing book: 15949 - Le Horror Altissime by Doyle, Arthur Conan
#   Total words in book: 9021
#   Fitted parameters with OLS: K = 2.6039, beta = 0.7515
#   Fitted parameters with curve_fit: K = 4.9257, beta = 0.6756
# Processing book: 15548 - Novena nga Pagdaydayao Quen Aputayo á Jesus Nazareno by nan
#   Total words in book: 4924
#   Fitted parameters with OLS: K = 2.1574, beta = 0.7574
#   Fitted parameters with curve_fit: K = 3.6146, beta = 0.6915
# Processing book: 15624 - Trisagio Quen Carcararag by Fojas, Justo Claudio
#   Total words in book: 5729
#   Fitted parameters with OLS: K = 2.2115, beta = 0.7544
#   Fitted parameters with curve_fit: K = 3.2937, beta = 0.7043
# Processing book: 15178 - Alaska by Jón Ólafsson
#   Total words in book: 29471
#   Fitted parameters with OLS: K = 2.4531, beta = 0.7646
#   Fitted parameters with curve_fit: K = 2.5991, beta = 0.7584
# Processing book: 16696 - Leiðarvísir í ástamálum  II. fyrir ungar stúlkur by Jónína Sigríður Jónsdóttir
#   Total words in book: 6730
#   Fitted parameters with OLS: K = 1.9928, beta = 0.7988
#   Fitted parameters with curve_fit: K = 3.9635, beta = 0.7145
# Processing book: 16846 - Mjallhvít: Æfintýri Handa Börnum by Grimm, Jacob;Grimm, Wilhelm
#   Total words in book: 6361
#   Fitted parameters with OLS: K = 2.5778, beta = 0.7396
#   Fitted parameters with curve_fit: K = 4.2760, beta = 0.6765
# Processing book: 17025 - Sæfarinn (Ferðin kring um hnöttin neðansjávar) by Verne, Jules
#   Total words in book: 37811
#   Fitted parameters with OLS: K = 3.1050, beta = 0.7357
#   Fitted parameters with curve_fit: K = 4.7844, beta = 0.6917
# Processing book: 19960 - Húsabætur á sveitabæjum: Uppdrættir og áætlanir by Jón Sveinsson
#   Total words in book: 8166
#   Fitted parameters with OLS: K = 2.4268, beta = 0.7256
#   Fitted parameters with curve_fit: K = 0.5832, beta = 0.8947
# Processing book: 22137 - Rímur af Grámanni í Garðshorni by Jón Hjaltason
#   Total words in book: 6368
#   Fitted parameters with OLS: K = 1.9819, beta = 0.8217
#   Fitted parameters with curve_fit: K = 6.2791, beta = 0.6795
# Processing book: 22139 - Leiðarvísir í ástamálum I. Karlmenn by Ingimundur Sveinsson
#   Total words in book: 6362
#   Fitted parameters with OLS: K = 2.0654, beta = 0.7851
#   Fitted parameters with curve_fit: K = 4.0248, beta = 0.7027
# Processing book: 1012 - La Divina Commedia di Dante by Dante Alighieri
#   Total words in book: 104877
#   Fitted parameters with OLS: K = 4.9059, beta = 0.6864
#   Fitted parameters with curve_fit: K = 8.1482, beta = 0.6396
# Processing book: 39988 - Storia comparata degli usi nuziali in Italia e presso gli altri popoli indo-europei Seconda edizione riveduta e ampliata dall'autore by De Gubernatis, Angelo
#   Total words in book: 69360
#   Fitted parameters with OLS: K = 2.5983, beta = 0.7678
#   Fitted parameters with curve_fit: K = 3.4661, beta = 0.7401
# Processing book: 43859 - Storia delle repubbliche italiane dei secoli di mezzo, v. 06 (of 16) by Sismondi, J.-C.-L. Simonde de (Jean-Charles-Léonard Simonde)
#   Total words in book: 81667
#   Fitted parameters with OLS: K = 6.3422, beta = 0.6631
#   Fitted parameters with curve_fit: K = 15.9980, beta = 0.5758
# Processing book: 44069 - Storia delle repubbliche italiane dei secoli di mezzo, v. 10 (of 16) by Sismondi, J.-C.-L. Simonde de (Jean-Charles-Léonard Simonde)
#   Total words in book: 83374
#   Fitted parameters with OLS: K = 5.8696, beta = 0.6671
#   Fitted parameters with curve_fit: K = 10.1225, beta = 0.6156
# Processing book: 45218 - Storia della decadenza e rovina dell'impero romano, volume 04 by Gibbon, Edward
#   Total words in book: 97943
#   Fitted parameters with OLS: K = 4.1109, beta = 0.7143
#   Fitted parameters with curve_fit: K = 7.1170, beta = 0.6635
# Processing book: 45219 - Storia della decadenza e rovina dell'impero romano, volume 05 by Gibbon, Edward
#   Total words in book: 104514
#   Fitted parameters with OLS: K = 4.3990, beta = 0.7126
#   Fitted parameters with curve_fit: K = 9.7779, beta = 0.6392
# Processing book: 45222 - Storia della decadenza e rovina dell'impero romano, volume 08 by Gibbon, Edward
#   Total words in book: 111769
#   Fitted parameters with OLS: K = 4.7661, beta = 0.7068
#   Fitted parameters with curve_fit: K = 9.1042, beta = 0.6475
# Processing book: 45227 - Storia della decadenza e rovina dell'impero romano, volume 13 by Gibbon, Edward
#   Total words in book: 119575
#   Fitted parameters with OLS: K = 5.0245, beta = 0.7006
#   Fitted parameters with curve_fit: K = 8.5323, beta = 0.6524
# Processing book: 49337 - Storia degli Italiani, vol. 01 (di 15) by Cantù, Cesare
#   Total words in book: 140749
#   Fitted parameters with OLS: K = 4.6478, beta = 0.7214
#   Fitted parameters with curve_fit: K = 7.2106, beta = 0.6818
# Processing book: 50641 - Istoria civile del Regno di Napoli, v. 1 by Giannone, Pietro
#   Total words in book: 115653
#   Fitted parameters with OLS: K = 4.9510, beta = 0.6827
#   Fitted parameters with curve_fit: K = 5.3033, beta = 0.6761
# Processing book: 27120 - Litanaiit Liturgiillo attoraksat illagêktunut Labradoremẽtunut by Anonymous
#   Total words in book: 19506
#   Fitted parameters with OLS: K = 1.2487, beta = 0.9025
#   Fitted parameters with curve_fit: K = 2.0626, beta = 0.8482
# Processing book: 1982 - 羅生門 by Akutagawa, Ryunosuke
#   Total words in book: 2947
#   Fitted parameters with OLS: K = 2.7181, beta = 0.6816
#   Fitted parameters with curve_fit: K = 2.1016, beta = 0.7154
# Processing book: 32978 - 下宿人 by Lowndes, Marie Belloc
#   Total words in book: 2972
#   Fitted parameters with OLS: K = 2.7914, beta = 0.6837
#   Fitted parameters with curve_fit: K = 2.5104, beta = 0.6970
# Processing book: 34158 - 入れかわった男 by Oppenheim, E. Phillips (Edward Phillips)
#   Total words in book: 2960
#   Fitted parameters with OLS: K = 2.7979, beta = 0.6832
#   Fitted parameters with curve_fit: K = 2.5071, beta = 0.6969
# Processing book: 34636 - 腕くらべ by Nagai, Kafu
#   Total words in book: 3141
#   Fitted parameters with OLS: K = 2.9566, beta = 0.6902
#   Fitted parameters with curve_fit: K = 4.2314, beta = 0.6406
# Processing book: 35018 - 雲形紋章 by Falkner, John Meade
#   Total words in book: 3034
#   Fitted parameters with OLS: K = 3.1783, beta = 0.6798
#   Fitted parameters with curve_fit: K = 4.4143, beta = 0.6340
# Processing book: 36459 - 羹 by Tanizaki, Jun'ichiro
#   Total words in book: 3028
#   Fitted parameters with OLS: K = 2.7803, beta = 0.6906
#   Fitted parameters with curve_fit: K = 3.2232, beta = 0.6695
# Processing book: 36976 - 裁判 by Rice, Elmer
#   Total words in book: 4293
#   Fitted parameters with OLS: K = 1.4621, beta = 0.7084
#   Fitted parameters with curve_fit: K = 0.0378, beta = 1.1796
# Processing book: 38697 - 殉情詩集 by Sato, Haruo
#   Total words in book: 3037
#   Fitted parameters with OLS: K = 3.1651, beta = 0.6848
#   Fitted parameters with curve_fit: K = 5.0894, beta = 0.6191
# Processing book: 39287 - 苦悶の欄 by Biggers, Earl Derr
#   Total words in book: 2960
#   Fitted parameters with OLS: K = 2.9906, beta = 0.6789
#   Fitted parameters with curve_fit: K = 3.1168, beta = 0.6720
# Processing book: 41325 - 幽霊書店 by Morley, Christopher
#   Total words in book: 4079
#   Fitted parameters with OLS: K = 2.8835, beta = 0.7634
#   Fitted parameters with curve_fit: K = 16.0322, beta = 0.5385
# Processing book: 218 - C. Iuli Caesaris De Bello Gallico, I-IV by Caesar, Julius
#   Total words in book: 23343
#   Fitted parameters with OLS: K = 2.7965, beta = 0.7724
# ...
#   Fitted parameters with OLS: K = 2.1622, beta = 0.8311
#   Fitted parameters with curve_fit: K = 3.6630, beta = 0.7772
# Processing book: 33598 - Język Polski, 1920, nr 3 (maj/czerwiec) by Nitsch, Kazimierz;Łoś, Jan;Rozwadowski, Jan Michał
#   Total words in book: 12868
#   Fitted parameters with OLS: K = 2.0761, beta = 0.8114
#   Fitted parameters with curve_fit: K = 1.6484, beta = 0.8367
# Processing book: 34079 - Tajemnica Baskerville'ów: dziwne przygody Sherlocka Holmes by Doyle, Arthur Conan
#   Total words in book: 37609
#   Fitted parameters with OLS: K = 3.0714, beta = 0.7702
#   Fitted parameters with curve_fit: K = 5.7252, beta = 0.7068
# Processing book: 34635 - Menazerya ludzka by Zapolska, Gabriela
#   Total words in book: 44913
#   Fitted parameters with OLS: K = 2.0693, beta = 0.8298
#   Fitted parameters with curve_fit: K = 3.2509, beta = 0.7848
# Processing book: 35301 - Łąka by Leśmian, Bolesław
#   Total words in book: 20837
#   Fitted parameters with OLS: K = 2.1381, beta = 0.8258
#   Fitted parameters with curve_fit: K = 4.7631, beta = 0.7393
# Processing book: 6000 - Ironia Pozorów by Łubieński, Maciej
#   Total words in book: 79219
#   Fitted parameters with OLS: K = 3.6563, beta = 0.7660
#   Fitted parameters with curve_fit: K = 7.3415, beta = 0.7001
# Processing book: 25840 - Versos de Bulhão Pato by Pato, Raimundo António de Bulhão
#   Total words in book: 23545
#   Fitted parameters with OLS: K = 3.3394, beta = 0.7171
#   Fitted parameters with curve_fit: K = 4.1410, beta = 0.6937
# Processing book: 31347 - Contos by Queirós, Eça de
#   Total words in book: 71456
#   Fitted parameters with OLS: K = 2.8004, beta = 0.7602
#   Fitted parameters with curve_fit: K = 5.3578, beta = 0.6987
# Processing book: 31509 - Obras Completas de Luis de Camões, Tomo II by Camões, Luís de
#   Total words in book: 89390
#   Fitted parameters with OLS: K = 6.3762, beta = 0.6641
#   Fitted parameters with curve_fit: K = 16.7944, beta = 0.5736
# Processing book: 31552 - Novo dicionário da língua portuguesa by Figueiredo, Cândido de
#   Total words in book: 1324599
#   Fitted parameters with OLS: K = 3.0648, beta = 0.7685
#   Fitted parameters with curve_fit: K = 5.6079, beta = 0.7233
# Processing book: 31971 - O crime do padre Amaro, scenas da vida devota by Queirós, Eça de
#   Total words in book: 135321
#   Fitted parameters with OLS: K = 6.6681, beta = 0.6548
#   Fitted parameters with curve_fit: K = 14.0813, beta = 0.5874
# Processing book: 3333 - Os Lusíadas by Camões, Luís de
#   Total words in book: 57729
#   Fitted parameters with OLS: K = 4.4677, beta = 0.6987
#   Fitted parameters with curve_fit: K = 7.5186, beta = 0.6479
# Processing book: 40409 - Os Maias: episodios da vida romantica by Queirós, Eça de
#   Total words in book: 205411
#   Fitted parameters with OLS: K = 9.6444, beta = 0.6254
#   Fitted parameters with curve_fit: K = 22.5793, beta = 0.5515
# Processing book: 55752 - Dom Casmurro by Machado de Assis
#   Total words in book: 66873
#   Fitted parameters with OLS: K = 5.8918, beta = 0.6613
#   Fitted parameters with curve_fit: K = 10.1964, beta = 0.6084
# Processing book: 62383 - A Biblia Sagrada, Contendo o Velho e o Novo Testamento by nan
#   Total words in book: 753652
#   Fitted parameters with OLS: K = 3.4186, beta = 0.6583
#   Fitted parameters with curve_fit: K = 1.9240, beta = 0.7031
# Processing book: 71031 - Principios e questões de philosophia politica (Vol. 1 of 2) by Cândido, António
#   Total words in book: 48641
#   Fitted parameters with OLS: K = 4.0747, beta = 0.7041
#   Fitted parameters with curve_fit: K = 9.1716, beta = 0.6238
# Processing book: 29470 - Embéo e Majaró Lucas by nan
#   Total words in book: 26210
#   Fitted parameters with OLS: K = 3.7684, beta = 0.6786
#   Fitted parameters with curve_fit: K = 3.7162, beta = 0.6797
# Processing book: 11756 - Creierul, O Enigma Descifrata by Moisa, Dorin Teodor
#   Total words in book: 79955
#   Fitted parameters with OLS: K = 4.0936, beta = 0.6635
#   Fitted parameters with curve_fit: K = 4.1179, beta = 0.6625
# Processing book: 35323 - Poezii by Eminescu, Mihai
#   Total words in book: 135591
#   Fitted parameters with OLS: K = 11.4448, beta = 0.6244
#   Fitted parameters with curve_fit: K = 36.6907, beta = 0.5193
# Processing book: 62916 - Povești by Slavici, Ioan
#   Total words in book: 51456
#   Fitted parameters with OLS: K = 3.7331, beta = 0.6797
#   Fitted parameters with curve_fit: K = 2.3880, beta = 0.7232
# Processing book: 64597 - Nuvele by Caragiale, I. L. (Ion Luca)
#   Total words in book: 34538
#   Fitted parameters with OLS: K = 3.8130, beta = 0.7252
#   Fitted parameters with curve_fit: K = 7.3684, beta = 0.6574
# Processing book: 65565 - Țara mea by Marie, Queen, consort of Ferdinand I, King of Romania
#   Total words in book: 48576
#   Fitted parameters with OLS: K = 4.2449, beta = 0.7115
#   Fitted parameters with curve_fit: K = 8.0573, beta = 0.6479
# Processing book: 14741 - Духовные оды by Derzhavin, Gavriil Romanovich
#   Total words in book: 20659
#   Fitted parameters with OLS: K = 1.8198, beta = 0.8398
#   Fitted parameters with curve_fit: K = 3.3024, beta = 0.7756
# Processing book: 16527 - 1001 задача для умственного счета by Rachinskii, Sergei Aleksandrovich
#   Total words in book: 24045
#   Fitted parameters with OLS: K = 3.5288, beta = 0.6622
#   Fitted parameters with curve_fit: K = 2.9509, beta = 0.6807
# Processing book: 30774 - Московия в представлении иностранцев XVI-XVII в. by Apostol, P. N. (Pavel Natanovich)
#   Total words in book: 8803
#   Fitted parameters with OLS: K = 1.5985, beta = 0.8644
#   Fitted parameters with curve_fit: K = 4.9168, beta = 0.7314
# Processing book: 37196 - Женское международное движение: Сборник статей by Various
#   Total words in book: 6446
#   Fitted parameters with OLS: K = 1.6339, beta = 0.8448
#   Fitted parameters with curve_fit: K = 5.9707, beta = 0.6857
# Processing book: 5316 - Красавице, которая нюхала табак by Pushkin, Aleksandr Sergeevich
#   Total words in book: 3116
#   Fitted parameters with OLS: K = 3.5049, beta = 0.6821
#   Fitted parameters with curve_fit: K = 7.1383, beta = 0.5846
# Processing book: 9000 - Sri Vishnu Sahasranaamam by Unknown
#   Total words in book: 4308
#   Fitted parameters with OLS: K = 1.5585, beta = 0.8781
#   Fitted parameters with curve_fit: K = 17.1898, beta = 0.5678
# Processing book: 49884 - The Æneid of Virgil Translated Into Scottish Verse. Volumes 1 & 2 by Virgil
#   Total words in book: 202716
#   Fitted parameters with OLS: K = 8.0694, beta = 0.6306
#   Fitted parameters with curve_fit: K = 15.0387, beta = 0.5764
# Processing book: 34126 - Za narodov blagor: Komedija v štirih dejanjih by Cankar, Ivan
#   Total words in book: 22351
#   Fitted parameters with OLS: K = 4.1842, beta = 0.6999
#   Fitted parameters with curve_fit: K = 8.2322, beta = 0.6269
# Processing book: 59722 - Janeza Trdine zbrani spisi 1: Bahovi huzarji in Iliri Spomini iz moje profesorske sluzbe na Hrvaskem (1853-1867) by Trdina, Janez
#   Total words in book: 81586
#   Fitted parameters with OLS: K = 3.7523, beta = 0.7427
#   Fitted parameters with curve_fit: K = 8.7871, beta = 0.6626
# Processing book: 73185 - Erotika by Cankar, Ivan
#   Total words in book: 11489
#   Fitted parameters with OLS: K = 2.2921, beta = 0.7911
#   Fitted parameters with curve_fit: K = 3.6781, beta = 0.7364
# Processing book: 75797 - Deseti brat : $b Izvirni roman by Jurčič, Josip
#   Total words in book: 69327
#   Fitted parameters with OLS: K = 5.4300, beta = 0.6915
#   Fitted parameters with curve_fit: K = 11.8589, beta = 0.6167
# Processing book: 11291 - Камено доба by Zujovic, Jovan
#   Total words in book: 38530
#   Fitted parameters with OLS: K = 2.8952, beta = 0.7610
#   Fitted parameters with curve_fit: K = 4.1940, beta = 0.7232
# Processing book: 11292 - Секунд вечности, источњачки роман by Ilić, Dragutin J.
#   Total words in book: 15585
#   Fitted parameters with OLS: K = 2.5303, beta = 0.7903
#   Fitted parameters with curve_fit: K = 4.6291, beta = 0.7228
# Processing book: 15008 - Свет by Nušić, Branislav
#   Total words in book: 23847
#   Fitted parameters with OLS: K = 4.9389, beta = 0.6658
#   Fitted parameters with curve_fit: K = 3.3248, beta = 0.7068
# Processing book: 14670 - Det går an by Almqvist, C. J. L. (Carl Jonas Love)
#   Total words in book: 39643
#   Fitted parameters with OLS: K = 4.7933, beta = 0.6840
#   Fitted parameters with curve_fit: K = 6.7904, beta = 0.6485
# Processing book: 29935 - Inferno by Strindberg, August
#   Total words in book: 47914
#   Fitted parameters with OLS: K = 3.1891, beta = 0.7542
#   Fitted parameters with curve_fit: K = 5.6633, beta = 0.6972
# Processing book: 48071 - Svarta fanor: Sedeskildringar från sekelskiftet by Strindberg, August
#   Total words in book: 71011
#   Fitted parameters with OLS: K = 3.5729, beta = 0.7318
#   Fitted parameters with curve_fit: K = 5.7796, beta = 0.6858
# Processing book: 49801 - Svensk litteraturhistoria by Forsberg, Hjalmar;Henrikz, H. H.
#   Total words in book: 28301
#   Fitted parameters with OLS: K = 3.5531, beta = 0.7371
#   Fitted parameters with curve_fit: K = 7.9226, beta = 0.6531
# Processing book: 51613 - Engelsk-Svensk och Svensk-Engelsk Ordbok Med Fullständig Uttalsbeteckning by Lönnkvist, Frederick
#   Total words in book: 78119
#   Fitted parameters with OLS: K = 3.2116, beta = 0.8092
#   Fitted parameters with curve_fit: K = 21.9575, beta = 0.6278
# Processing book: 57052 - Röda rummet: Skildringar ur artist- och författarlivet by Strindberg, August
#   Total words in book: 99043
#   Fitted parameters with OLS: K = 4.5102, beta = 0.7006
#   Fitted parameters with curve_fit: K = 6.0838, beta = 0.6727
# Processing book: 57357 - Svenska folk-sagor och äfventyr. Första delen (häfte 1 och häfte 2) by nan
#   Total words in book: 174416
#   Fitted parameters with OLS: K = 15.5023, beta = 0.5315
#   Fitted parameters with curve_fit: K = 28.7413, beta = 0.4770
# Processing book: 76006 - Frosten : $b Skildring från 1860-talets Västerbotten by Väring, Astrid
#   Total words in book: 86401
#   Fitted parameters with OLS: K = 4.9542, beta = 0.6866
#   Fitted parameters with curve_fit: K = 6.1537, beta = 0.6661
# Processing book: 76471 - Vintermyren : $b berättelse by Väring, Astrid
#   Total words in book: 97729
#   Fitted parameters with OLS: K = 4.6646, beta = 0.6851
#   Fitted parameters with curve_fit: K = 5.0541, beta = 0.6774
# Processing book: 76549 - Jubelklangen : $b Andliga sånger by nan
#   Total words in book: 35985
#   Fitted parameters with OLS: K = 5.5478, beta = 0.6348
#   Fitted parameters with curve_fit: K = 6.8660, beta = 0.6127
# Processing book: 39004 - శుభలేఖ by Ramamohan Rao, Mahidhara
#   Total words in book: 3926
#   Fitted parameters with OLS: K = 1.3023, beta = 0.7311
#   Fitted parameters with curve_fit: K = 0.0770, beta = 1.1002
# Processing book: 39561 - అగ్నిగుండం by Ramamohan Rao, Mahidhara
#   Total words in book: 3851
#   Fitted parameters with OLS: K = 1.2164, beta = 0.7459
#   Fitted parameters with curve_fit: K = 0.1090, beta = 1.0621
# Processing book: 40687 - కొల్లాయి గట్టితే నేమి? by Ramamohan Rao, Mahidhara
#   Total words in book: 6150
#   Fitted parameters with OLS: K = 2.9591, beta = 0.5879
#   Fitted parameters with curve_fit: K = 0.0053, beta = 1.3600
# Processing book: 41845 - ఓనమాలు by Ramamohan Rao, Mahidhara
#   Total words in book: 4675
#   Fitted parameters with OLS: K = 1.2865, beta = 0.7034
#   Fitted parameters with curve_fit: K = 0.0080, beta = 1.3477
# Processing book: 43220 - కత్తుల వంతెన by Ramamohan Rao, Mahidhara
#   Total words in book: 4220
#   Fitted parameters with OLS: K = 1.2382, beta = 0.7229
#   Fitted parameters with curve_fit: K = 0.0252, beta = 1.2259
# Processing book: 50178 - ఈ దారి ఎక్కడికి? (రధచక్రాలు - ఉత్తరగాధ) by Ramamohan Rao, Mahidhara
#   Total words in book: 4728
#   Fitted parameters with OLS: K = 1.4668, beta = 0.6906
#   Fitted parameters with curve_fit: K = 0.0116, beta = 1.3044
# Processing book: 13687 - Dakilang Asal by Tolentino, Aurelio
#   Total words in book: 6996
#   Fitted parameters with OLS: K = 2.2742, beta = 0.7584
#   Fitted parameters with curve_fit: K = 3.0939, beta = 0.7204
# Processing book: 15845 - Florante at Laura by Balagtas, Francisco
#   Total words in book: 24350
#   Fitted parameters with OLS: K = 2.3912, beta = 0.7727
#   Fitted parameters with curve_fit: K = 8.5082, beta = 0.6384
# Processing book: 15980 - Pag Susulatan nang Dalauang Binibini na si Urbana at ni Feliza by Castro, Modesto  de
#   Total words in book: 37689
#   Fitted parameters with OLS: K = 2.5909, beta = 0.7402
#   Fitted parameters with curve_fit: K = 2.6000, beta = 0.7395
# Processing book: 16157 - Ibong Adarna  Corrido at Buhay na Pinagdaanan nang tatlong Principeng Magcacapatid na Anac nang Haring Fernando at nang Reina Valeriana sa Cahariang Berbania by Anonymous
#   Total words in book: 19011
#   Fitted parameters with OLS: K = 3.4969, beta = 0.6895
#   Fitted parameters with curve_fit: K = 3.9503, beta = 0.6758
# Processing book: 16656 - Dimasalang Kalendariong Tagalog (1922) by López, Honorio
#   Total words in book: 13609
#   Fitted parameters with OLS: K = 2.6868, beta = 0.7445
#   Fitted parameters with curve_fit: K = 3.5579, beta = 0.7121
# Processing book: 17116 - Ang Liham ni Dr. Jose Rizal sa mga Kadalagahan sa Malolos, Bulakan by Rizal, José
#   Total words in book: 6329
#   Fitted parameters with OLS: K = 1.8343, beta = 0.7911
#   Fitted parameters with curve_fit: K = 3.1074, beta = 0.7261
# Processing book: 18141 - ¡Caiñgat Cayo!  Sa mañga masasamang libro,t, casulatan by Rodriguez, Fr. José
#   Total words in book: 6610
#   Fitted parameters with OLS: K = 2.5911, beta = 0.7300
#   Fitted parameters with curve_fit: K = 3.4325, beta = 0.6947
# Processing book: 20228 - Noli Me Tangere by Rizal, José
#   Total words in book: 153394
#   Fitted parameters with OLS: K = 4.0591, beta = 0.7142
#   Fitted parameters with curve_fit: K = 7.0621, beta = 0.6651
# Processing book: 46639 - Ang Pag-ibig ng Layas by Sevilla, Jose N.
#   Total words in book: 41012
#   Fitted parameters with OLS: K = 3.7994, beta = 0.7057
#   Fitted parameters with curve_fit: K = 7.5272, beta = 0.6367
# Processing book: 47629 - Ang "Filibusterismo" (Karugtóng ng Noli Me Tangere) by Rizal, José
#   Total words in book: 104174
#   Fitted parameters with OLS: K = 3.9425, beta = 0.7079
#   Fitted parameters with curve_fit: K = 5.1919, beta = 0.6825
# Processing book: 23825 - 施公案 by Anonymous
#   Total words in book: 4352
#   Fitted parameters with OLS: K = 1.9352, beta = 0.8672
#   Fitted parameters with curve_fit: K = 21.8906, beta = 0.5535
# Processing book: 23962 - 西遊記 by Wu, Cheng'en
#   Total words in book: 3383
#   Fitted parameters with OLS: K = 3.6043, beta = 0.7233
#   Fitted parameters with curve_fit: K = 19.4694, beta = 0.4961
# Processing book: 24162 - 二刻拍案惊奇 by Ling, Mengchu
#   Total words in book: 4798
#   Fitted parameters with OLS: K = 1.6623, beta = 0.8869
#   Fitted parameters with curve_fit: K = 16.1783, beta = 0.5968
# Processing book: 25128 - 孽海花 by Zeng, Pu
#   Total words in book: 2995
#   Fitted parameters with OLS: K = 3.7259, beta = 0.6653
#   Fitted parameters with curve_fit: K = 6.0048, beta = 0.5990
# Processing book: 25134 - 九尾狐 by Pinghuazhuren
#   Total words in book: 3146
#   Fitted parameters with OLS: K = 3.9702, beta = 0.6842
#   Fitted parameters with curve_fit: K = 12.8193, beta = 0.5243
# Processing book: 25142 - 王陽明全集 by Wang, Yangming
#   Total words in book: 5544
#   Fitted parameters with OLS: K = 1.6127, beta = 0.8828
#   Fitted parameters with curve_fit: K = 10.3252, beta = 0.6506
# Processing book: 25187 - 花月痕 by Wei, Zi'an
#   Total words in book: 3028
#   Fitted parameters with OLS: K = 3.9218, beta = 0.6664
#   Fitted parameters with curve_fit: K = 7.8175, beta = 0.5712
# Processing book: 25346 - 南腔北調集 by Lu, Xun
#   Total words in book: 4010
#   Fitted parameters with OLS: K = 2.2045, beta = 0.7963
#   Fitted parameters with curve_fit: K = 11.8078, beta = 0.5766
# Processing book: 25559 - 中國小說史略 by Lu, Xun
#   Total words in book: 4409
#   Fitted parameters with OLS: K = 1.8789, beta = 0.8543
#   Fitted parameters with curve_fit: K = 16.6665, beta = 0.5726
# Processing book: 25716 - 灵历集光 by Song, Shangjie
#   Total words in book: 4079
#   Fitted parameters with OLS: K = 2.6962, beta = 0.7860
#   Fitted parameters with curve_fit: K = 18.5773, beta = 0.5333

# %%
plt.figure(figsize=(18, 6))
plt.xticks(rotation=45)
sns.boxenplot(y="beta", x="language", data=parameters)
plt.xlabel("Language")
plt.ylabel("Beta Parameter")
plt.title("Distribution of Fitted Beta Parameter by Language")
# Out:
# Text(0.5, 1.0, 'Distribution of Fitted Beta Parameter by Language')
